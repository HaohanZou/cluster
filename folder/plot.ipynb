# %%
import torch 
import torch.nn.functional as F
import numpy as np
import timeit 
import matplotlib.pyplot as plt
import sympy as sym
import pandas as pd

# %%
loss_1 = pd.read_csv("dict_of_lists.csv").astype('double')
loss_1_b = loss_1[['best']]
loss_1_q = loss_1[['quantile']]

loss_2 = pd.read_csv("dict_of_lists_1.csv").astype('double')
loss_2_b = loss_2[['best']]
loss_2_q = loss_2[['quantile']]


loss_3 = pd.read_csv("dict_of_lists_2.csv").astype('double')
loss_3_b = loss_3[['best']]
loss_3_q = loss_3[['quantile']]


loss_4 = pd.read_csv("dict_of_lists_3.csv").astype('double')
loss_4_b = loss_4[['best']]
loss_4_q = loss_4[['quantile']]

# %%
loss_1 = pd.read_csv("log/fn_d_all_p_5_2024-09-25-182620_1/dso_fn_d_all_p_5_13.csv").astype('double')
loss_1_b = loss_1[['r_max']]
loss_1_q = loss_1[['r_avg_sub']]

# %%
plt.figure(figsize=(10, 6))
agents = np.array(loss_1.index)
plt.plot(agents, loss_1_b, label = "r_max")

# plt.plot(agents, loss_1_q, label='r_avg_sub')



# Add labels and title

plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Best Reward of each Trail')
plt.legend()
plt.grid(True)
plt.ylim((-0,1.1))
plt.show()

# %%
plt.figure(figsize=(10, 6))
agents = np.array(loss_1.index)
# plt.plot(agents, loss_1_b, label = "r_max")

plt.plot(agents, loss_1_q, label='r_avg_sub')



# Add labels and title

plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Best Reward of each Trail')
plt.legend()
plt.grid(True)
plt.ylim((-1000,1.0))
plt.show()

# %%
loss_2 = pd.read_csv("log/fn_d_all_p_5_2024-09-25-185726_21/dso_fn_d_all_p_5_13.csv").astype('double')
loss_2_b = loss_2[['r_max']]
loss_2_q = loss_2[['r_avg_sub']]

# %%
plt.figure(figsize=(10, 6))
agents = np.array(loss_2.index)
plt.plot(agents, loss_2_b, label = "r_max")

# plt.plot(agents, loss_1_q, label='r_avg_sub')

# Add labels and title

plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Best Reward of each Trail')
plt.legend()
plt.grid(True)
plt.ylim((-0,1.1))
plt.show()

# %%
plt.figure(figsize=(10, 6))
agents = np.array(loss_2.index)
# plt.plot(agents, loss_1_b, label = "r_max")

plt.plot(agents, loss_2_q, label='r_avg_sub')



# Add labels and title

plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Best Reward of each Trail')
plt.legend()
plt.grid(True)
plt.ylim((-1000,10.0))
plt.show()

# %%
loss_3 = pd.read_csv("log/fn_d_all_p_5_2024-09-27-191419_42/dso_fn_d_all_p_5_13.csv").astype('double')
loss_3_b = loss_3[['r_max']]
loss_3_q = loss_3[['r_avg_sub']]

# %%
plt.figure(figsize=(10, 6))
agents = np.array(loss_3.index)
plt.plot(agents, loss_3_b, label = "r_max")

# plt.plot(agents, loss_1_q, label='r_avg_sub')



# Add labels and title

plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Best Reward of each Trail')
plt.legend()
plt.grid(True)
plt.ylim((-0,1.1))
plt.show()

# %%
plt.figure(figsize=(10, 6))
agents = np.array(loss_3.index)
# plt.plot(agents, loss_1_b, label = "r_max")

plt.plot(agents, loss_3_q, label='r_avg_sub')



# Add labels and title

plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Best Reward of each Trail')
plt.legend()
plt.grid(True)
plt.ylim((-1000,10.0))
plt.show()

# %%
loss_4 = pd.read_csv("log/fn_d_all_p_5_2024-09-27-194042_7/dso_fn_d_all_p_5_13.csv").astype('double')
loss_4_b = loss_4[['r_max']]
loss_4_q = loss_4[['r_avg_sub']]

# %%
plt.figure(figsize=(10, 6))
agents = np.array(loss_4.index)
plt.plot(agents, loss_4_b, label = "r_max")

# plt.plot(agents, loss_1_q, label='r_avg_sub')



# Add labels and title

plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Best Reward of each Trail')
plt.legend()
plt.grid(True)
plt.ylim((-0,1.1))
plt.show()

# %%
plt.figure(figsize=(10, 6))
agents = np.array(loss_4.index)
# plt.plot(agents, loss_1_b, label = "r_max")

plt.plot(agents, loss_4_q, label='r_avg_sub')



# Add labels and title

plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Best Reward of each Trail')
plt.legend()
plt.grid(True)
plt.ylim((-1000,10.0))
plt.show()

# %%
loss_5 = pd.read_csv("log/fn_d_all_k_5_2024-09-29-140801_13/dso_fn_d_all_k_5_13.csv").astype('double')
loss_5_b = loss_5[['r_max']]
loss_5_q = loss_5[['r_avg_sub']]

# %%
plt.figure(figsize=(10, 6))
agents = np.array(loss_5.index)
plt.plot(agents, loss_5_b, label = "r_max")

# plt.plot(agents, loss_1_q, label='r_avg_sub')



# Add labels and title

plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Best Reward of each Trail')
plt.legend()
plt.grid(True)
plt.ylim((-0,1.1))
plt.show()

# %%
plt.figure(figsize=(10, 6))
agents = np.array(loss_5.index)
# plt.plot(agents, loss_1_b, label = "r_max")

plt.plot(agents, loss_5_q, label='r_avg_sub')



# Add labels and title

plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Best Reward of each Trail')
plt.legend()
plt.grid(True)
plt.ylim((-1000,10.0))
plt.show()

# %%
loss_6 = pd.read_csv("log/fn_d_all_m_5_2024-09-30-233125_7/dso_fn_d_all_m_5_13.csv").astype('double')
loss_6_b = loss_6[['r_max']]
loss_6_q = loss_6[['r_avg_sub']]

# %%
plt.figure(figsize=(10, 6))
agents = np.array(loss_6.index)
plt.plot(agents, loss_6_b, label = "r_max")

# plt.plot(agents, loss_1_q, label='r_avg_sub')



# Add labels and title

plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Best Reward of each Trail')
plt.legend()
plt.grid(True)
plt.ylim((-0,1.1))
plt.show()

# %%
plt.figure(figsize=(10, 6))
agents = np.array(loss_6.index)
# plt.plot(agents, loss_1_b, label = "r_max")

plt.plot(agents, loss_6_q, label='r_avg_sub')



# Add labels and title

plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Best Reward of each Trail')
plt.legend()
plt.grid(True)
plt.ylim((-1000,10.0))
plt.show()

# %%
choice = np.argmax([loss_1.shape[0], loss_2.shape[0], loss_3.shape[0], loss_4.shape[0]])
choice
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[140], line 1
# ----> 1 choice = np.argmax([loss_1.shape[0], loss_2.shape[0], loss_3.shape[0], loss_4.shape[0]])
#       2 choice
#
# NameError: name 'loss_1' is not defined

# %%
max_length = loss_2.shape[0]

def pad_1(obj, target):
    if len(obj) < target:
        add_temp = np.ones(target - len(obj))
        add_temp = pd.Series(add_temp)
        obj=pd.concat([obj, add_temp])
    return obj


loss_1_b = pd.DataFrame(pad_1(loss_1_b, max_length), columns = ['best'])
loss_1_q = pd.DataFrame(pad_1(loss_1_q, max_length), columns = ['quantile'])


loss_3_b = pd.DataFrame(pad_1(loss_3_b, max_length), columns = ['best'])
loss_3_q = pd.DataFrame(pad_1(loss_3_q, max_length), columns = ['quantile'])

loss_4_b = pd.DataFrame(pad_1(loss_4_b, max_length), columns = ['best'])
loss_4_q = pd.DataFrame(pad_1(loss_4_q, max_length), columns = ['quantile'])

plt.figure(figsize=(10, 6))
agents = np.array(loss_2.index)
plt.plot(agents, loss_1_b, label = "trail 1")

plt.plot(agents, loss_2_b, label='trail 2')

plt.plot(agents, loss_3_b, label='trail 3')

plt.plot(agents, loss_4_b, label='trail 4')


# Add labels and title

plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Best Reward of each Trail')
plt.legend()
plt.grid(True)
plt.ylim((0.75,1.1))
plt.show()

# %%
plt.figure(figsize=(10, 6))
agents = np.array(loss_2.index)
plt.plot(agents, loss_1_q, label = "trail 1")

plt.plot(agents, loss_2_q, label='trail 2')

plt.plot(agents, loss_3_q, label='trail 3')

plt.plot(agents, loss_4_q, label='trail 4')


# Add labels and title

plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Quantile Reward of each Trail')
plt.legend()
plt.grid(True)
plt.ylim((0.75,1.1))
plt.show()

# %%
''
agents = np.array(loss_2.index)
plt.plot(agents, loss_1_b)
# plt.fill_between(agents, mean_b - var_b, mean_b + var_b, alpha=0.3)

# plt.plot(agents, loww_2_b, label='quantile')
# plt.fill_between(agents, mean_q - var_q, mean_q + var_q, alpha=0.3)


# Add labels and title
plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Average Reward (No PGD)')
plt.legend()
plt.grid(True)
plt.show()

# %%
df_b = loss_1_b.merge(loss_2_b, left_index = True, right_index=True)
df_b = df_b.merge(loss_3_b, left_index = True, right_index=True)
df_b = df_b.merge(loss_4_b, left_index = True, right_index=True)

df_q = loss_1_q.merge(loss_2_q, left_index = True, right_index=True)
df_q = df_q.merge(loss_3_q, left_index = True, right_index=True)
df_q = df_q.merge(loss_4_q, left_index = True, right_index=True)
# Out:
# /tmp/ipykernel_3749273/3549664883.py:3: FutureWarning: Passing 'suffixes' which cause duplicate columns {'best_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df_b = df_b.merge(loss_4_b, left_index = True, right_index=True)
# /tmp/ipykernel_3749273/3549664883.py:7: FutureWarning: Passing 'suffixes' which cause duplicate columns {'quantile_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df_q = df_q.merge(loss_4_q, left_index = True, right_index=True)

# %%
mean_b = np.array(df_b.apply(np.mean, axis = 1))
var_b = np.array(df_b.apply(np.std, axis = 1))

mean_q = np.array(df_q.apply(np.mean, axis = 1))
var_q = np.array(df_q.apply(np.std, axis = 1))

# %%
agents = np.array(df_b.index)
plt.plot(agents, mean_b, label='best')
# plt.fill_between(agents, mean_b - var_b, mean_b + var_b, alpha=0.3)

plt.plot(agents, mean_q, label='quantile')
# plt.fill_between(agents, mean_q - var_q, mean_q + var_q, alpha=0.3)


# Add labels and title
plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Average Reward in First 9 Epochs (No PGD)')
plt.legend()
plt.grid(True)
plt.show()

# %%
df_2_b = loss_2_b.merge(loss_4_b, left_index = True, right_index=True)
df_2_q = loss_2_q.merge(loss_4_q, left_index = True, right_index=True)

# %%
mean_2_b = np.array(df_2_b.apply(np.mean, axis = 1))
mean_2_q = np.array(df_2_q.apply(np.mean, axis = 1))

# %%
agents = np.array(df_2_b.index[13:])
plt.plot(agents, mean_2_b[13:], label='best')
# plt.fill_between(agents, mean_b - var_b, mean_b + var_b, alpha=0.3)

plt.plot(agents, mean_2_q[13:], label='quantile')
# plt.fill_between(agents, mean_q - var_q, mean_q + var_q, alpha=0.3)


# Add labels and title
plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Average Reward (Has PGD)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 8D Loss Curve

# %%
df = pd.read_csv("log/fn_d_all_k_5_2024-09-10-133127_13/dso_fn_d_all_k_5_13.csv").astype('double')
df.columns
# Out:
# Index(['r_best', 'r_max', 'r_avg_full', 'r_avg_sub', 'l_avg_full', 'l_avg_sub',
#        'ewma', 'n_unique_full', 'n_unique_sub', 'n_novel_full', 'n_novel_sub',
#        'a_ent_full', 'a_ent_sub', 'invalid_avg_full', 'invalid_avg_sub',
#        'baseline', 'time'],
#       dtype='object')

# %%
agents = np.array(df.index)[2:]
plt.plot(agents, df['r_max'][2:], label='best')
# plt.fill_between(agents, mean_b - var_b, mean_b + var_b, alpha=0.3)

plt.plot(agents, df['r_avg_sub'][2:], label='quantile_mean')
# plt.fill_between(agents, mean_q - var_q, mean_q + var_q, alpha=0.3)

# plt.plot(agents, df['ewma'][5:], label = "baseline")


# Add labels and title
plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Reward Trajectory of 8D - 1')
plt.legend()
plt.grid(True)
plt.show()

# %%
df = pd.read_csv("log/fn_d_all_k_5_2024-09-10-183544_13/dso_fn_d_all_k_5_13.csv").astype('double')
df.columns
# Out:
# Index(['r_best', 'r_max', 'r_avg_full', 'r_avg_sub', 'l_avg_full', 'l_avg_sub',
#        'ewma', 'n_unique_full', 'n_unique_sub', 'n_novel_full', 'n_novel_sub',
#        'a_ent_full', 'a_ent_sub', 'invalid_avg_full', 'invalid_avg_sub',
#        'baseline', 'time'],
#       dtype='object')

# %%
agents = np.array(df.index)[2:]
plt.plot(agents, df['r_max'][2:], label='best')
# plt.fill_between(agents, mean_b - var_b, mean_b + var_b, alpha=0.3)

plt.plot(agents, df['r_avg_sub'][2:], label='quantile_mean')
# plt.fill_between(agents, mean_q - var_q, mean_q + var_q, alpha=0.3)


# Add labels and title
plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Reward Trajectory of 8D - 2')
plt.legend()
plt.grid(True)
plt.show()

# %%
loss_1 = pd.read_csv("log/fn_d_all_p_5_2024-11-27-143144_42/dso_fn_d_all_p_5_13.csv").astype('double')
loss_1_b = loss_1[['r_max']]
loss_1_q = loss_1[['r_top']]

# %%
plt.figure(figsize=(10, 6))
agents = np.array(loss_1.index)
plt.plot(agents, loss_1_b, label = "r_max")
plt.plot(agents, loss_1_q, label='r_top')



# Add labels and title

plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Best Reward of each Trail')
plt.legend()
plt.grid(True)
plt.ylim((-0,1.1))
plt.show()

# %%
loss_2 = pd.read_csv("log/fn_d_all_p_5_2024-11-26-202841_21/dso_fn_d_all_p_5_13.csv").astype('double')
loss_2_b = loss_2[['r_max']]
loss_2_q = loss_2[['r_top']]

# %%
plt.figure(figsize=(10, 6))
agents = np.array(loss_2.index)
plt.plot(agents, loss_2_b, label = "r_max")
plt.plot(agents, loss_2_q, label='r_top')



# Add labels and title

plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Best Reward of each Trail')
plt.legend()
plt.grid(True)
plt.ylim((-0,1.1))
plt.show()

# %%
loss_5 = pd.read_csv("log/fn_d_all_p_5_2024-11-26-202158_5/dso_fn_d_all_p_5_13.csv").astype('double')
loss_5_b = loss_5[['r_max']]
loss_5_q = loss_5[['r_top']]

# %%
plt.figure(figsize=(10, 6))
agents = np.array(loss_5.index)
plt.plot(agents, loss_5_b, label = "r_max")
plt.plot(agents, loss_5_q, label='r_top')



# Add labels and title

plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Best Reward of each Trail')
plt.legend()
plt.grid(True)
plt.ylim((-0,1.1))
plt.show()

# %%
loss_3 = pd.read_csv("log/fn_d_all_p_5_2024-11-27-152950_5/dso_fn_d_all_p_5_13.csv").astype('double')
loss_3_b = loss_3[['r_max']]
loss_3_q = loss_3[['r_top']]

# %%
plt.figure(figsize=(10, 6))
agents = np.array(loss_3.index)
plt.plot(agents, loss_3_b, label = "r_max")
plt.plot(agents, loss_3_q, label='r_top')



# Add labels and title

plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Best Reward of each Trail')
plt.legend()
plt.grid(True)
plt.ylim((-0,1.1))
plt.show()

# %%
loss_4 = pd.read_csv("log/fn_d_all_p_5_2024-11-27-215543_28/dso_fn_d_all_p_5_13.csv").astype('double')
loss_4_b = loss_4[['r_max']]
loss_4_q = loss_4[['r_top']]

# %%
plt.figure(figsize=(10, 6))
agents = np.array(loss_4.index)
plt.plot(agents, loss_4_b, label = "r_max")
plt.plot(agents, loss_4_q, label='r_top')



# Add labels and title

plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Best Reward of each Trail')
plt.legend()
plt.grid(True)
plt.ylim((-0,1.1))
plt.show()

# %%
loss_6 = pd.read_csv("log/fn_d_all_p_5_2024-11-28-183120_42/dso_fn_d_all_p_5_13.csv").astype('double')
loss_6_b = loss_6[['r_max']]
loss_6_q = loss_6[['r_top']]

# %%
plt.figure(figsize=(10, 6))
agents = np.array(loss_6.index)
plt.plot(agents, loss_6_b, label = "r_max")
plt.plot(agents, loss_6_q, label='r_top')



# Add labels and title

plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Best Reward of each Trail')
plt.legend()
plt.grid(True)
plt.ylim((-0,1.1))
plt.show()

# %%
loss_7 = pd.read_csv("log/fn_d_all_p_5_2024-11-28-172648_29/dso_fn_d_all_p_5_13.csv").astype('double')
loss_7_b = loss_7[['r_max']]
loss_7_q = loss_7[['r_top']]

# %%
plt.figure(figsize=(10, 6))
agents = np.array(loss_7.index)
plt.plot(agents, loss_7_b, label = "r_max")
plt.plot(agents, loss_7_q, label='r_top')



# Add labels and title

plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Best Reward of each Trail')
plt.legend()
plt.grid(True)
plt.ylim((-0,1.1))
plt.show()

# %%
loss_8 = pd.read_csv("log/fn_d_all_t_5_2024-12-17-205645_28/dso_fn_d_all_t_5_13.csv").astype('double')
loss_8_b = loss_8[['r_max']]
loss_8_q = loss_8[['r_top']]

# %%
plt.figure(figsize=(10, 6))
agents = np.array(loss_8.index)
plt.plot(agents, loss_8_b, label = "r_max")
plt.plot(agents, loss_8_q, label='r_top')



# Add labels and title

plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Best Reward of each Trail')
plt.legend()
plt.grid(True)
plt.ylim((-0,1.1))
plt.show()

# %%
loss_9 = pd.read_csv("log/fn_d_all_t_5_2024-12-17-214046_28/dso_fn_d_all_t_5_13.csv").astype('double')
loss_9_b = loss_9[['r_max']]
loss_9_q = loss_9[['r_top']]

# %%
plt.figure(figsize=(10, 6))
agents = np.array(loss_9.index)
plt.plot(agents, loss_9_b, label = "r_max")
plt.plot(agents, loss_9_q, label='r_top')



# Add labels and title

plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Best Reward of each Trail')
plt.legend()
plt.grid(True)
plt.ylim((-0,1.1))
plt.show()

# %%
loss_10 = pd.read_csv("log/fn_d_all_t_5_2024-12-17-230209_13/dso_fn_d_all_t_5_13.csv").astype('double')
loss_10_b = loss_10[['r_max']]
loss_10_q = loss_10[['r_top']]

# %%
plt.figure(figsize=(10, 6))
agents = np.array(loss_10.index)
plt.plot(agents, loss_10_b, label = "r_max")
plt.plot(agents, loss_10_q, label='r_top')



# Add labels and title

plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Best Reward of each Trail')
plt.legend()
plt.grid(True)
plt.ylim((-0,1.1))
plt.show()

# %%
loss_11 = pd.read_csv("log/fn_d_all_t_5_2024-12-19-163918_21/dso_fn_d_all_t_5_13.csv").astype('double')
loss_11_b = loss_11[['r_max']]
loss_11_q = loss_11[['r_top']]

# %%
plt.figure(figsize=(10, 6))
agents = np.array(loss_11.index)
plt.plot(agents, loss_11_b, label = "r_max")
plt.plot(agents, loss_11_q, label='r_top')



# Add labels and title

plt.xlabel('epoch')
plt.ylabel('Reward')
plt.title('Best Reward of each Trail')
plt.legend()
plt.grid(True)
plt.ylim((-0,1.1))
plt.show()
